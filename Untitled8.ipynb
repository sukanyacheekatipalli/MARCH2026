# %%
full_name = "Sukanya_Cheekatipalli"
cource_name = "Data_Engineering"

# %%
full_name
# Out:
# 'Sukanya_Cheekatipalli'

# %%
cource_name
# Out:
# 'Data_Engineering'

# %%
full_title = full_name + " " + cource_name
print(full_title)
# Out:
# Sukanya_Cheekatipalli Data_Engineering

# %%
name_length =len(full_name)
print(f"1. Length of '{full_name}': {name_length}")
# Out:
# 1. Length of 'Sukanya_Cheekatipalli': 21

# %%
first_char = full_name[0]
print(f"1. First character of '{full_name}': {first_char}")
# Out:
# 1. First character of 'Sukanya_Cheekatipalli': S

# %%
middle = full_name[1:-1]
print(f"7. Middle part of '{full_name}': '{middle}'")
# Out:
# 7. Middle part of 'Sukanya_Cheekatipalli': 'ukanya_Cheekatipall'

# %%
lower_full_name = full_name.lower()
print(f"1. Lowercase full_name: '{lower_full_name}'")
# Out:
# 1. Lowercase full_name: 'sukanya_cheekatipalli'

# %%
upper_full_name = full_name.upper()
print(f"1. uppercase full_name: '{upper_full_name}'")
# Out:
# 1. uppercase full_name: 'SUKANYA_CHEEKATIPALLI'

# %%
lower_cource_name = cource_name.lower()
print(f"1. Lowercase cource_name: '{lower_cource_name}'")
# Out:
# 1. Lowercase cource_name: 'data_engineering'

# %%
upper_cource_name = cource_name.upper()
print(f"1. uppercase cource_name: '{upper_cource_name}'")
# Out:
# 1. uppercase cource_name: 'DATA_ENGINEERING'

# %%
full_name = " Sukanya_Cheekatipalli "
cource_name = full_name.strip()
print(f"1. Stripped input: '{cource_name}'")
# Out:
# 1. Stripped input: 'Sukanya_Cheekatipalli'

# %%
cource_name = " Data Enginnering "
full_name = cource_name.strip()
print(f"1. Stripped input: '{full_name}")
# Out:
# 1. Stripped input: 'Data Enginnering

# %%
cource_name = " Data Engineering "
left_stripped = cource_name.lstrip()
print(f"2. Left-stripped: '{left_stripped}'")
# Out:
# 2. Left-stripped: 'Data Engineering '

# %%
full_name = " Sukanya Cheekatipalli "
left_stripped = full_name.lstrip()
print(f"2. Left-stripped: '{left_stripped}'")
# Out:
# 2. Left-stripped: 'Sukanya Cheekatipalli '

# %%
name = "vemu institute"
right_stripped = name.rstrip()
print(f"3. Right-stripped: '{right_stripped}'")
# Out:
# 3. Right-stripped: 'vemu institute'

# %%
course_name = " Data Engineering "
tech_stack = " Python,SQL,Git "
institute = "Edukron"

# %%
words = course_name.split()
print(f"1. words: {words}")
# Out:
# 1. words: ['Data', 'Engineering']

# %%
words = tech_stack.split()
print(f'1. words: {words}')
# Out:
# 1. words: ['Python,SQL,Git']

# %%
words = tech_stack.split(',')
print(f'1. words: {words}')
# Out:
# 1. words: [' Python', 'SQL', 'Git ']

# %%
joined_courses = ", ".join(course_name)
print(f"1. Joined courses: '{joined_courses}'")
# Out:
# 1. Joined courses: ' , D, a, t, a,  , E, n, g, i, n, e, e, r, i, n, g,  '

# %%
joined_skills = "-".join(tech_stack)
print(f"2. Joined skills: '{joined_skills}'")
# Out:
# 2. Joined skills: ' -P-y-t-h-o-n-,-S-Q-L-,-G-i-t- '
